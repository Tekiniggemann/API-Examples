# %% [markdown]
# # 1st API
#  ### crypto currency. was pretty clean dataframe

# %%
import json
import pandas as pd
import requests

response = requests.get('https://api.coinpaprika.com/v1/coins')
#results = response.json()
#results

# %%
data = pd.DataFrame(results)
data.head(10)
# Out:
#                  id          name symbol  rank  is_new  is_active   type
# 0       btc-bitcoin       Bitcoin    BTC     1   False       True   coin
# 1      eth-ethereum      Ethereum    ETH     2   False       True   coin
# 2  bnb-binance-coin  Binance Coin    BNB     3   False       True   coin
# 3       usdt-tether        Tether   USDT     4   False       True  token
# 4        sol-solana        Solana    SOL     5   False       True  token
# 5       ada-cardano       Cardano    ADA     6   False       True   coin
# 6           hex-hex           HEX    HEX     7   False       True  token
# 7           xrp-xrp           XRP    XRP     8   False       True   coin
# 8      dot-polkadot      Polkadot    DOT     9   False       True   coin
# 9     doge-dogecoin      Dogecoin   DOGE    10   False       True   coin

# %% [markdown]
# # 2nd API

# %%
resp = requests.get('https://www.fruityvice.com/api/fruit/all')
resp = resp.json()
#resp

# %%
fruit = pd.DataFrame(resp)
fruit.head(10)
# Out:
#       genus       name  id     family         order  \
# 0     Malus      Apple   6   Rosaceae       Rosales
# 1    Prunus    Apricot  35   Rosaceae       Rosales
# 2      Musa     Banana   1   Musaceae  Zingiberales
# 3  Fragaria  Blueberry  33   Rosaceae       Rosales
# 4    Prunus     Cherry   9   Rosaceae          None
# 5     Durio     Durian  60  Malvaceae      Malvales
# 6     Vitis     Grapes  47   Vitaceae       Vitales
# 7   Psidium      Guava  37  Myrtaceae      Myrtales
# 8    Citrus      Lemon  26   Rutaceae    Sapindales
# 9    Citrus       Lime  44   Rutaceae    Sapindales
#
#                                           nutritions
# 0  {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1  {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2  {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 3  {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 4  {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 5  {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# ...

# %%
def flatten(fruit, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(fruit[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        fruit = pd.concat([fruit, flattened], axis=1)
        fruit = fruit.drop(column, axis=1)
    return fruit

# %%
dict(fruit['nutritions'])
pd.DataFrame(dict(fruit['nutritions']))
pd.DataFrame(dict(fruit['nutritions'])).transpose()
# Out:
#     carbohydrates  protein   fat  calories  sugar
# 0           11.40     0.30  0.40      52.0  10.30
# 1            3.90     0.50  0.10      15.0   3.20
# 2           22.00     1.00  0.20      96.0  17.20
# 3            5.50     0.00  0.40      29.0   5.40
# 4           12.00     1.00  0.30      50.0   8.00
# 5           27.10     1.50  5.30     147.0   6.75
# 6           18.10     0.72  0.16      69.0  15.48
# 7           14.00     2.60  1.00      68.0   9.00
# 8            9.00     1.10  0.30      29.0   2.50
# 9            8.40     0.30  0.10      25.0   1.70
# 10          15.00     0.82  0.38      60.0  13.70
# 11           8.00     0.00  0.00      34.0   8.00
# 12           8.30     1.00  0.20      43.0   8.20
# 13          11.00     0.00  0.40      43.0   1.00
# 14          15.00     0.40  0.10      57.0  10.00
# 15          18.00     0.00  0.00      81.0  18.00
# 16          13.12     0.54  0.12      50.0   9.85
# 17          12.00     1.20  0.70      53.0   4.40
# ...

# %%
nested_columns = ['nutritions']

flat = flatten(fruit, nested_columns)
flat
# Out:
#         genus        name  id         family          order  \
# 0       Malus       Apple   6       Rosaceae        Rosales
# 1      Prunus     Apricot  35       Rosaceae        Rosales
# 2        Musa      Banana   1       Musaceae   Zingiberales
# 3    Fragaria   Blueberry  33       Rosaceae        Rosales
# 4      Prunus      Cherry   9       Rosaceae           None
# 5       Durio      Durian  60      Malvaceae       Malvales
# 6       Vitis      Grapes  47       Vitaceae        Vitales
# 7     Psidium       Guava  37      Myrtaceae       Myrtales
# 8      Citrus       Lemon  26       Rutaceae     Sapindales
# 9      Citrus        Lime  44       Rutaceae     Sapindales
# 10  Mangifera       Mango  27  Anacardiaceae     Sapindales
# 11    Cucumis       Melon  41  Cucurbitaceae  Cucurbitaceae
# 12     Citrus      Orange   2       Rutaceae     Sapindales
# 13     Carica      Papaya  42     Caricaceae      Caricacea
# 14      Pyrus        Pear   4       Rosaceae        Rosales
# ...

# %% [markdown]
# # 3rd API

# %%
# https://whiskyhunter.net/api/auction_data/catawiki/

# %%
whisky = requests.get('https://whiskyhunter.net/api/auction_data/catawiki/')
whisky = whisky.json()
#whisky

# %%
whisky = pd.DataFrame(whisky)
whisky.head(10)
# Out:
#            dt  winning_bid_max  winning_bid_min  winning_bid_mean  \
# 0  2021-10-01          12677.0              1.0            175.99
# 1  2021-09-01           8997.0              1.0            177.90
# 2  2021-08-01           4779.0              3.0            170.76
# 3  2021-07-01           7699.0              9.0            188.65
# 4  2021-06-01           5576.0              9.0            179.78
# 5  2021-05-01           5212.0              9.0            178.74
# 6  2021-04-01           8094.0              5.0            162.83
# 7  2021-03-01           8656.0             14.0            187.35
# 8  2021-02-01           5292.0              9.0            187.78
# 9  2021-01-01           6293.0              7.0            194.09
#
#    auction_trading_volume  auction_lots_count  all_auctions_lots_count  \
# 0                743018.0                4222                    43263
# 1                729223.0                4099                    38295
# ...
